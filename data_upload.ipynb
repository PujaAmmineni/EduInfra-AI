# %%
import os
import re
import streamlit as st
from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient, generate_blob_sas
from datetime import datetime, timedelta
from dotenv import load_dotenv
from azure.ai.formrecognizer import DocumentAnalysisClient
from azure.core.credentials import AzureKeyCredential
from azure.search.documents import SearchClient
from openai import AzureOpenAI
from azure.storage.blob import BlobSasPermissions
from azure.storage.blob import ContentSettings

# %% [markdown]
# Change the container env variables as per the course data

# %%
# Load environment variables from .env file
load_dotenv()

# Set up Azure Blob Storage credentials
AZURE_CONNECTION_STRING = os.getenv("AZURE_CONNECTION_STRING")
AZURE_ACCOUNT_NAME = os.getenv("AZURE_ACCOUNT_NAME")
AZURE_ACCOUNT_KEY = os.getenv("AZURE_ACCOUNT_KEY")
CONTAINER_NAME = os.getenv("CCE_4360_CONTAINER_NAME")

# Set up Azure Document Intelligence credentials
FORM_RECOGNIZER_ENDPOINT = os.getenv("AZURE_FORM_RECOGNIZER_ENDPOINT")
FORM_RECOGNIZER_KEY = os.getenv("AZURE_FORM_RECOGNIZER_KEY")

# Set up Azure OpenAI credentials
AZURE_OPENAI_ENDPOINT = os.getenv("AZURE_OPENAI_ENDPOINT")
AZURE_OPENAI_KEY = os.getenv("AZURE_OPENAI_API_KEY")
AZURE_OPENAI_DEPLOYMENT_NAME = os.getenv("AZURE_OPENAI_EMB_DEPLOYMENT_NAME")

# Set up Azure AI Search credentials
SEARCH_ENDPOINT = os.getenv("AZURE_SEARCH_ENDPOINT")
SEARCH_INDEX_NAME = os.getenv("CCE_4360_AZURE_SEARCH_INDEX_NAME")
SEARCH_API_KEY = os.getenv("AZURE_SEARCH_API_KEY")

# %%
# Initialize clients
blob_service_client = BlobServiceClient.from_connection_string(AZURE_CONNECTION_STRING)
document_analysis_client = DocumentAnalysisClient(FORM_RECOGNIZER_ENDPOINT, AzureKeyCredential(FORM_RECOGNIZER_KEY))
openai_client = AzureOpenAI(
    api_key=AZURE_OPENAI_KEY,
    api_version="2023-05-15",  # Use the latest supported version
    azure_endpoint=AZURE_OPENAI_ENDPOINT
)
search_client = SearchClient(endpoint=SEARCH_ENDPOINT, index_name=SEARCH_INDEX_NAME, credential=AzureKeyCredential(SEARCH_API_KEY))

# %%
# Function to sanitize document keys
def sanitize_key(key):
    # Replace spaces and invalid characters with underscores
    return re.sub(r"[^a-zA-Z0-9_=-]", "_", key)

# %%
from azure.storage.blob import generate_blob_sas, BlobSasPermissions
import os
from datetime import datetime, timedelta
from azure.storage.blob import BlobServiceClient

def upload_to_blob_storage(file_path):
    """
    Uploads a file to Azure Blob Storage and generates a SAS URL valid for 365 days.
    
    Parameters:
    - file_path (str): Local file path

    Returns:
    - tuple: (SAS URL, document_name) if successful, else (None, None)
    """
    try:
        # Extract file name from the path
        document_name = os.path.basename(file_path)

        # Initialize Blob Service Client
        container_client = blob_service_client.get_container_client(CONTAINER_NAME)
        if not container_client.exists():
            container_client.create_container()

        blob_client = container_client.get_blob_client(document_name)

        # Upload the file
        with open(file_path, "rb") as file_data:
            blob_client.upload_blob(file_data, overwrite=True,content_settings=ContentSettings(content_type='application/pdf'))

        print(f"✅ File '{document_name}' uploaded successfully.")

        # Generate SAS token with 365-day expiry
        expiry_time = datetime.utcnow() + timedelta(days=365)

        sas_token = generate_blob_sas(
            account_name=AZURE_ACCOUNT_NAME,
            container_name=CONTAINER_NAME,
            blob_name=document_name,
            account_key=AZURE_ACCOUNT_KEY,
            permission=BlobSasPermissions(read=True, list=True),
            expiry=expiry_time  # ✅ Set expiry to 365 days
        )

        # Construct the SAS URL
        sas_url = f"https://{AZURE_ACCOUNT_NAME}.blob.core.windows.net/{CONTAINER_NAME}/{document_name}?{sas_token}"
        print(f"✅ SAS URL generated successfully! Expires on: {expiry_time}")
        print(f"✅ SAS URL: {sas_url}")

        return sas_url, document_name  # ✅ Return both SAS URL and document name

    except Exception as e:
        print(f"❌ Error uploading file: {e}")
        return None, None

# %%
def analyze_layout(document_url):
    """
    Extract text from a document using Azure Form Recognizer.
    """
    try:
        print(f"🔹 Debug: Trying to analyze document from URL: {document_url}")  # ✅ Print SAS URL for debugging
        poller = document_analysis_client.begin_analyze_document_from_url("prebuilt-layout", document_url)
        return poller.result()
    except Exception as e:
        print(f"❌ Error analyzing document layout: {e}")
        return None

# %%
# Function to generate embeddings using Azure OpenAI
def generate_embedding(text):
    """
    Generate text embeddings using Azure OpenAI.

    Parameters:
    - text (str): Text to embed

    Returns:
    - List[float]: Embedding vector
    """
    try:
        response = openai_client.embeddings.create(
            input=text,
            model=AZURE_OPENAI_DEPLOYMENT_NAME
        )
        return response.data[0].embedding
    except Exception as e:
        print(f"❌ Error generating embedding: {e}")
        return None

# %%
def process_and_store_document(document_url, document_name):
    """
    Process a document, extract text, generate embeddings, and store in Azure AI Search 
    along with the SAS URL.

    Parameters:
    - document_url (str): The SAS URL of the document.
    - document_name (str): Name of the document.

    Returns:
    - str: Success or error message.
    """
    try:
        # Step 1: Analyze the document layout (extract text)
        result = analyze_layout(document_url)
        if not result:
            return "❌ Failed to analyze document."

        # Step 2: Iterate through pages and process each
        for page in result.pages:
            page_text = " ".join([line.content for line in page.lines])  # Extract text
            embedding = generate_embedding(page_text)  # Generate embedding

            # Sanitize the document key
            document_key = sanitize_key(f"{document_name}_{page.page_number}")

            # Step 3: Construct the document for Azure AI Search
            document = {
                "id": document_key,
                "document_name": document_name,  # ✅ File name is now correctly set
                "page_number": page.page_number,
                "content": page_text,  # ✅ Storing extracted text
                "embedding": embedding,  # ✅ Storing embedding
                "sas_url": document_url  # ✅ Storing SAS URL
            }

            # Step 4: Upload the document to Azure AI Search
            search_client.upload_documents(documents=[document])
            print(f"🔹 Debug: Checking Azure Search Index Status")
            print(search_client.get_document_count())

        return f"✅ Document '{document_name}' processed and stored successfully!"
    

    except Exception as e:
        return f"❌ Error processing and storing document: {e}"

# %%
import os

# Define the folder containing PDFs
folder_path = "/Users/aakashwalavalkar/Downloads/CCE 4360 processed"  # Change this to the actual folder path

# Iterate through each PDF in the folder
for filename in os.listdir(folder_path):
    if filename.lower().endswith(".pdf"):  # Process only PDF files
        file_path = os.path.join(folder_path, filename)

        # Upload and get SAS URL
        sas_url, document_name = upload_to_blob_storage(file_path)

        if sas_url:
            result = process_and_store_document(sas_url, document_name)
            print(f"Processed {filename}: {result}")
        else:
            print(f"Failed to upload {filename}")
# Out:
# ✅ File '2 - Introduction - Detailed Estimating and Bidding.pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-07-09 12:11:08.137329
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/cce-4360/2 - Introduction - Detailed Estimating and Bidding.pdf?se=2026-07-09T12%3A11%3A08Z&sp=r&sv=2025-05-05&sr=b&sig=E6uJIJbxy52VVtYcTSwQWlvymtChG3U%2B7x4LGzl/3LQ%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/cce-4360/2 - Introduction - Detailed Estimating and Bidding.pdf?se=2026-07-09T12%3A11%3A08Z&sp=r&sv=2025-05-05&sr=b&sig=E6uJIJbxy52VVtYcTSwQWlvymtChG3U%2B7x4LGzl/3LQ%3D
# 🔹 Debug: Checking Azure Search Index Status
# 0
# 🔹 Debug: Checking Azure Search Index Status
# 2
# 🔹 Debug: Checking Azure Search Index Status
# 2
# 🔹 Debug: Checking Azure Search Index Status
# 4
# 🔹 Debug: Checking Azure Search Index Status
# 5
# 🔹 Debug: Checking Azure Search Index Status
# 5
# 🔹 Debug: Checking Azure Search Index Status
# 6
# 🔹 Debug: Checking Azure Search Index Status
# 7
# 🔹 Debug: Checking Azure Search Index Status
# 8
# 🔹 Debug: Checking Azure Search Index Status
# 9
# 🔹 Debug: Checking Azure Search Index Status
# 11
# 🔹 Debug: Checking Azure Search Index Status
# 12
# 🔹 Debug: Checking Azure Search Index Status
# 12
# 🔹 Debug: Checking Azure Search Index Status
# 13
# 🔹 Debug: Checking Azure Search Index Status
# 14
# 🔹 Debug: Checking Azure Search Index Status
# 15
# 🔹 Debug: Checking Azure Search Index Status
# 16
# 🔹 Debug: Checking Azure Search Index Status
# 18
# 🔹 Debug: Checking Azure Search Index Status
# 19
# 🔹 Debug: Checking Azure Search Index Status
# 19
# 🔹 Debug: Checking Azure Search Index Status
# 20
# 🔹 Debug: Checking Azure Search Index Status
# 21
# 🔹 Debug: Checking Azure Search Index Status
# 22
# 🔹 Debug: Checking Azure Search Index Status
# 23
# 🔹 Debug: Checking Azure Search Index Status
# 25
# 🔹 Debug: Checking Azure Search Index Status
# 26
# 🔹 Debug: Checking Azure Search Index Status
# 27
# 🔹 Debug: Checking Azure Search Index Status
# 28
# 🔹 Debug: Checking Azure Search Index Status
# 28
# 🔹 Debug: Checking Azure Search Index Status
# 29
# 🔹 Debug: Checking Azure Search Index Status
# 30
# 🔹 Debug: Checking Azure Search Index Status
# 31
# 🔹 Debug: Checking Azure Search Index Status
# 33
# 🔹 Debug: Checking Azure Search Index Status
# 34
# 🔹 Debug: Checking Azure Search Index Status
# 34
# 🔹 Debug: Checking Azure Search Index Status
# 35
# 🔹 Debug: Checking Azure Search Index Status
# 36
# 🔹 Debug: Checking Azure Search Index Status
# 37
# 🔹 Debug: Checking Azure Search Index Status
# 38
# 🔹 Debug: Checking Azure Search Index Status
# 39
# 🔹 Debug: Checking Azure Search Index Status
# 40
# Processed 2 - Introduction - Detailed Estimating and Bidding.pdf: ✅ Document '2 - Introduction - Detailed Estimating and Bidding.pdf' processed and stored successfully!
# ✅ File '8 Term Project Handbook.pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-07-09 12:12:12.431235
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/cce-4360/8 Term Project Handbook.pdf?se=2026-07-09T12%3A12%3A12Z&sp=r&sv=2025-05-05&sr=b&sig=FUYRtzPql2ZUUkXC1dhzwjfSe/I%2BotzNkTreRlQVQLg%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/cce-4360/8 Term Project Handbook.pdf?se=2026-07-09T12%3A12%3A12Z&sp=r&sv=2025-05-05&sr=b&sig=FUYRtzPql2ZUUkXC1dhzwjfSe/I%2BotzNkTreRlQVQLg%3D
# 🔹 Debug: Checking Azure Search Index Status
# 41
# 🔹 Debug: Checking Azure Search Index Status
# 43
# 🔹 Debug: Checking Azure Search Index Status
# 43
# 🔹 Debug: Checking Azure Search Index Status
# 44
# 🔹 Debug: Checking Azure Search Index Status
# 45
# 🔹 Debug: Checking Azure Search Index Status
# 47
# 🔹 Debug: Checking Azure Search Index Status
# 47
# 🔹 Debug: Checking Azure Search Index Status
# 48
# 🔹 Debug: Checking Azure Search Index Status
# 49
# 🔹 Debug: Checking Azure Search Index Status
# 50
# 🔹 Debug: Checking Azure Search Index Status
# 52
# 🔹 Debug: Checking Azure Search Index Status
# 52
# 🔹 Debug: Checking Azure Search Index Status
# 53
# 🔹 Debug: Checking Azure Search Index Status
# 54
# 🔹 Debug: Checking Azure Search Index Status
# 55
# 🔹 Debug: Checking Azure Search Index Status
# 57
# 🔹 Debug: Checking Azure Search Index Status
# 57
# 🔹 Debug: Checking Azure Search Index Status
# 58
# 🔹 Debug: Checking Azure Search Index Status
# 59
# 🔹 Debug: Checking Azure Search Index Status
# 60
# 🔹 Debug: Checking Azure Search Index Status
# 62
# 🔹 Debug: Checking Azure Search Index Status
# 62
# 🔹 Debug: Checking Azure Search Index Status
# 63
# 🔹 Debug: Checking Azure Search Index Status
# 64
# 🔹 Debug: Checking Azure Search Index Status
# 66
# Processed 8 Term Project Handbook.pdf: ✅ Document '8 Term Project Handbook.pdf' processed and stored successfully!
# ✅ File '1 - Course Introduction.pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-07-09 12:12:52.295598
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/cce-4360/1 - Course Introduction.pdf?se=2026-07-09T12%3A12%3A52Z&sp=r&sv=2025-05-05&sr=b&sig=XrAqI1AYur%2BDLbpsh0edH3RSWbJEZHNBxYpLP2AdAZM%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/cce-4360/1 - Course Introduction.pdf?se=2026-07-09T12%3A12%3A52Z&sp=r&sv=2025-05-05&sr=b&sig=XrAqI1AYur%2BDLbpsh0edH3RSWbJEZHNBxYpLP2AdAZM%3D
# 🔹 Debug: Checking Azure Search Index Status
# 67
# 🔹 Debug: Checking Azure Search Index Status
# 68
# 🔹 Debug: Checking Azure Search Index Status
# 68
# 🔹 Debug: Checking Azure Search Index Status
# 69
# 🔹 Debug: Checking Azure Search Index Status
# 70
# 🔹 Debug: Checking Azure Search Index Status
# 72
# 🔹 Debug: Checking Azure Search Index Status
# 72
# 🔹 Debug: Checking Azure Search Index Status
# 73
# 🔹 Debug: Checking Azure Search Index Status
# 74
# 🔹 Debug: Checking Azure Search Index Status
# 75
# 🔹 Debug: Checking Azure Search Index Status
# 76
# 🔹 Debug: Checking Azure Search Index Status
# 77
# 🔹 Debug: Checking Azure Search Index Status
# 79
# 🔹 Debug: Checking Azure Search Index Status
# 79
# 🔹 Debug: Checking Azure Search Index Status
# 80
# 🔹 Debug: Checking Azure Search Index Status
# 81
# 🔹 Debug: Checking Azure Search Index Status
# 82
# Processed 1 - Course Introduction.pdf: ✅ Document '1 - Course Introduction.pdf' processed and stored successfully!
# ✅ File '5 - Concrete.pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-07-09 12:13:17.405528
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/cce-4360/5 - Concrete.pdf?se=2026-07-09T12%3A13%3A17Z&sp=r&sv=2025-05-05&sr=b&sig=Dlo4egIlH4k2bdh7f3rE7JpYVmq3T9wx2iiJ4K/ck8s%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/cce-4360/5 - Concrete.pdf?se=2026-07-09T12%3A13%3A17Z&sp=r&sv=2025-05-05&sr=b&sig=Dlo4egIlH4k2bdh7f3rE7JpYVmq3T9wx2iiJ4K/ck8s%3D
# 🔹 Debug: Checking Azure Search Index Status
# 83
# 🔹 Debug: Checking Azure Search Index Status
# 85
# 🔹 Debug: Checking Azure Search Index Status
# 85
# 🔹 Debug: Checking Azure Search Index Status
# 86
# 🔹 Debug: Checking Azure Search Index Status
# 87
# 🔹 Debug: Checking Azure Search Index Status
# 89
# 🔹 Debug: Checking Azure Search Index Status
# 89
# 🔹 Debug: Checking Azure Search Index Status
# 90
# 🔹 Debug: Checking Azure Search Index Status
# 91
# 🔹 Debug: Checking Azure Search Index Status
# 92
# 🔹 Debug: Checking Azure Search Index Status
# 93
# 🔹 Debug: Checking Azure Search Index Status
# 95
# 🔹 Debug: Checking Azure Search Index Status
# 95
# 🔹 Debug: Checking Azure Search Index Status
# 96
# 🔹 Debug: Checking Azure Search Index Status
# 97
# 🔹 Debug: Checking Azure Search Index Status
# 99
# 🔹 Debug: Checking Azure Search Index Status
# 99
# 🔹 Debug: Checking Azure Search Index Status
# 100
# 🔹 Debug: Checking Azure Search Index Status
# 101
# 🔹 Debug: Checking Azure Search Index Status
# 102
# 🔹 Debug: Checking Azure Search Index Status
# 104
# 🔹 Debug: Checking Azure Search Index Status
# 104
# 🔹 Debug: Checking Azure Search Index Status
# 105
# 🔹 Debug: Checking Azure Search Index Status
# 106
# 🔹 Debug: Checking Azure Search Index Status
# 108
# 🔹 Debug: Checking Azure Search Index Status
# 108
# 🔹 Debug: Checking Azure Search Index Status
# 109
# 🔹 Debug: Checking Azure Search Index Status
# 110
# 🔹 Debug: Checking Azure Search Index Status
# 112
# 🔹 Debug: Checking Azure Search Index Status
# 112
# 🔹 Debug: Checking Azure Search Index Status
# 113
# Processed 5 - Concrete.pdf: ✅ Document '5 - Concrete.pdf' processed and stored successfully!
# ✅ File '8 - Computer-based estimating.pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-07-09 12:13:56.170311
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/cce-4360/8 - Computer-based estimating.pdf?se=2026-07-09T12%3A13%3A56Z&sp=r&sv=2025-05-05&sr=b&sig=D/RcVF6stMeXswcJWORB1Sqzzznu7S/HsT/SoaHokH8%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/cce-4360/8 - Computer-based estimating.pdf?se=2026-07-09T12%3A13%3A56Z&sp=r&sv=2025-05-05&sr=b&sig=D/RcVF6stMeXswcJWORB1Sqzzznu7S/HsT/SoaHokH8%3D
# 🔹 Debug: Checking Azure Search Index Status
# 115
# 🔹 Debug: Checking Azure Search Index Status
# 115
# 🔹 Debug: Checking Azure Search Index Status
# 116
# 🔹 Debug: Checking Azure Search Index Status
# 117
# 🔹 Debug: Checking Azure Search Index Status
# 118
# 🔹 Debug: Checking Azure Search Index Status
# 119
# 🔹 Debug: Checking Azure Search Index Status
# 120
# 🔹 Debug: Checking Azure Search Index Status
# 122
# 🔹 Debug: Checking Azure Search Index Status
# 122
# 🔹 Debug: Checking Azure Search Index Status
# 123
# 🔹 Debug: Checking Azure Search Index Status
# 125
# 🔹 Debug: Checking Azure Search Index Status
# 125
# 🔹 Debug: Checking Azure Search Index Status
# 126
# 🔹 Debug: Checking Azure Search Index Status
# 127
# 🔹 Debug: Checking Azure Search Index Status
# 128
# 🔹 Debug: Checking Azure Search Index Status
# 130
# 🔹 Debug: Checking Azure Search Index Status
# 130
# 🔹 Debug: Checking Azure Search Index Status
# 131
# Processed 8 - Computer-based estimating.pdf: ✅ Document '8 - Computer-based estimating.pdf' processed and stored successfully!
# ✅ File '9 Navisworks Overview Nov. 4.pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-07-09 12:15:13.542184
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/cce-4360/9 Navisworks Overview Nov. 4.pdf?se=2026-07-09T12%3A15%3A13Z&sp=r&sv=2025-05-05&sr=b&sig=c4r6rT/us3wztDmyF%2BnaTzNiD3Z99g/rQfQeqxxmtKU%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/cce-4360/9 Navisworks Overview Nov. 4.pdf?se=2026-07-09T12%3A15%3A13Z&sp=r&sv=2025-05-05&sr=b&sig=c4r6rT/us3wztDmyF%2BnaTzNiD3Z99g/rQfQeqxxmtKU%3D
# 🔹 Debug: Checking Azure Search Index Status
# 133
# 🔹 Debug: Checking Azure Search Index Status
# 134
# 🔹 Debug: Checking Azure Search Index Status
# 135
# 🔹 Debug: Checking Azure Search Index Status
# 135
# 🔹 Debug: Checking Azure Search Index Status
# 136
# 🔹 Debug: Checking Azure Search Index Status
# 137
# 🔹 Debug: Checking Azure Search Index Status
# 138
# 🔹 Debug: Checking Azure Search Index Status
# 139
# 🔹 Debug: Checking Azure Search Index Status
# 140
# 🔹 Debug: Checking Azure Search Index Status
# 142
# 🔹 Debug: Checking Azure Search Index Status
# 143
# 🔹 Debug: Checking Azure Search Index Status
# 143
# 🔹 Debug: Checking Azure Search Index Status
# 144
# 🔹 Debug: Checking Azure Search Index Status
# 145
# 🔹 Debug: Checking Azure Search Index Status
# 146
# 🔹 Debug: Checking Azure Search Index Status
# 147
# 🔹 Debug: Checking Azure Search Index Status
# 148
# 🔹 Debug: Checking Azure Search Index Status
# 149
# 🔹 Debug: Checking Azure Search Index Status
# 151
# 🔹 Debug: Checking Azure Search Index Status
# 152
# 🔹 Debug: Checking Azure Search Index Status
# 152
# 🔹 Debug: Checking Azure Search Index Status
# 153
# 🔹 Debug: Checking Azure Search Index Status
# 154
# 🔹 Debug: Checking Azure Search Index Status
# 155
# 🔹 Debug: Checking Azure Search Index Status
# 156
# 🔹 Debug: Checking Azure Search Index Status
# 157
# 🔹 Debug: Checking Azure Search Index Status
# 158
# 🔹 Debug: Checking Azure Search Index Status
# 159
# 🔹 Debug: Checking Azure Search Index Status
# 161
# 🔹 Debug: Checking Azure Search Index Status
# 161
# 🔹 Debug: Checking Azure Search Index Status
# 162
# 🔹 Debug: Checking Azure Search Index Status
# 163
# Processed 9 Navisworks Overview Nov. 4.pdf: ✅ Document '9 Navisworks Overview Nov. 4.pdf' processed and stored successfully!
# ✅ File '3 - Labor & Equipment.pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-07-09 12:16:00.930417
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/cce-4360/3 - Labor & Equipment.pdf?se=2026-07-09T12%3A16%3A00Z&sp=r&sv=2025-05-05&sr=b&sig=/L82YMNZleM0Q9j0pKNOXdDdBqFAe7xuV2aNkazhr64%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/cce-4360/3 - Labor & Equipment.pdf?se=2026-07-09T12%3A16%3A00Z&sp=r&sv=2025-05-05&sr=b&sig=/L82YMNZleM0Q9j0pKNOXdDdBqFAe7xuV2aNkazhr64%3D
# 🔹 Debug: Checking Azure Search Index Status
# 164
# 🔹 Debug: Checking Azure Search Index Status
# 165
# 🔹 Debug: Checking Azure Search Index Status
# 167
# 🔹 Debug: Checking Azure Search Index Status
# 167
# 🔹 Debug: Checking Azure Search Index Status
# 168
# 🔹 Debug: Checking Azure Search Index Status
# 169
# 🔹 Debug: Checking Azure Search Index Status
# 170
# 🔹 Debug: Checking Azure Search Index Status
# 171
# 🔹 Debug: Checking Azure Search Index Status
# 172
# 🔹 Debug: Checking Azure Search Index Status
# 173
# 🔹 Debug: Checking Azure Search Index Status
# 174
# 🔹 Debug: Checking Azure Search Index Status
# 175
# 🔹 Debug: Checking Azure Search Index Status
# 176
# 🔹 Debug: Checking Azure Search Index Status
# 178
# 🔹 Debug: Checking Azure Search Index Status
# 178
# 🔹 Debug: Checking Azure Search Index Status
# 179
# 🔹 Debug: Checking Azure Search Index Status
# 180
# 🔹 Debug: Checking Azure Search Index Status
# 181
# 🔹 Debug: Checking Azure Search Index Status
# 182
# 🔹 Debug: Checking Azure Search Index Status
# 183
# 🔹 Debug: Checking Azure Search Index Status
# 185
# 🔹 Debug: Checking Azure Search Index Status
# 186
# 🔹 Debug: Checking Azure Search Index Status
# 186
# 🔹 Debug: Checking Azure Search Index Status
# 187
# 🔹 Debug: Checking Azure Search Index Status
# 188
# 🔹 Debug: Checking Azure Search Index Status
# 189
# 🔹 Debug: Checking Azure Search Index Status
# 190
# 🔹 Debug: Checking Azure Search Index Status
# 191
# 🔹 Debug: Checking Azure Search Index Status
# 192
# 🔹 Debug: Checking Azure Search Index Status
# 194
# 🔹 Debug: Checking Azure Search Index Status
# 194
# 🔹 Debug: Checking Azure Search Index Status
# 195
# 🔹 Debug: Checking Azure Search Index Status
# 196
# 🔹 Debug: Checking Azure Search Index Status
# 197
# 🔹 Debug: Checking Azure Search Index Status
# 198
# 🔹 Debug: Checking Azure Search Index Status
# 200
# 🔹 Debug: Checking Azure Search Index Status
# 200
# 🔹 Debug: Checking Azure Search Index Status
# 201
# 🔹 Debug: Checking Azure Search Index Status
# 202
# 🔹 Debug: Checking Azure Search Index Status
# 203
# 🔹 Debug: Checking Azure Search Index Status
# 204
# 🔹 Debug: Checking Azure Search Index Status
# 206
# 🔹 Debug: Checking Azure Search Index Status
# 207
# 🔹 Debug: Checking Azure Search Index Status
# 207
# 🔹 Debug: Checking Azure Search Index Status
# 208
# Processed 3 - Labor & Equipment.pdf: ✅ Document '3 - Labor & Equipment.pdf' processed and stored successfully!
# ✅ File '6 - Masonry.pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-07-09 12:17:38.185212
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/cce-4360/6 - Masonry.pdf?se=2026-07-09T12%3A17%3A38Z&sp=r&sv=2025-05-05&sr=b&sig=nRPXV5WFTQnFQrY4hh4IUy7SR%2Bv4uTpMPxJozbFHjKo%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/cce-4360/6 - Masonry.pdf?se=2026-07-09T12%3A17%3A38Z&sp=r&sv=2025-05-05&sr=b&sig=nRPXV5WFTQnFQrY4hh4IUy7SR%2Bv4uTpMPxJozbFHjKo%3D
# 🔹 Debug: Checking Azure Search Index Status
# 209
# 🔹 Debug: Checking Azure Search Index Status
# 211
# 🔹 Debug: Checking Azure Search Index Status
# 212
# 🔹 Debug: Checking Azure Search Index Status
# 212
# 🔹 Debug: Checking Azure Search Index Status
# 213
# 🔹 Debug: Checking Azure Search Index Status
# 214
# 🔹 Debug: Checking Azure Search Index Status
# 215
# 🔹 Debug: Checking Azure Search Index Status
# 216
# 🔹 Debug: Checking Azure Search Index Status
# 218
# 🔹 Debug: Checking Azure Search Index Status
# 219
# 🔹 Debug: Checking Azure Search Index Status
# 220
# 🔹 Debug: Checking Azure Search Index Status
# 220
# 🔹 Debug: Checking Azure Search Index Status
# 221
# 🔹 Debug: Checking Azure Search Index Status
# 222
# 🔹 Debug: Checking Azure Search Index Status
# 223
# 🔹 Debug: Checking Azure Search Index Status
# 224
# 🔹 Debug: Checking Azure Search Index Status
# 225
# 🔹 Debug: Checking Azure Search Index Status
# 227
# 🔹 Debug: Checking Azure Search Index Status
# 228
# 🔹 Debug: Checking Azure Search Index Status
# 228
# 🔹 Debug: Checking Azure Search Index Status
# 229
# 🔹 Debug: Checking Azure Search Index Status
# 230
# 🔹 Debug: Checking Azure Search Index Status
# 231
# 🔹 Debug: Checking Azure Search Index Status
# 232
# 🔹 Debug: Checking Azure Search Index Status
# 233
# 🔹 Debug: Checking Azure Search Index Status
# 235
# 🔹 Debug: Checking Azure Search Index Status
# 235
# 🔹 Debug: Checking Azure Search Index Status
# 236
# 🔹 Debug: Checking Azure Search Index Status
# 237
# 🔹 Debug: Checking Azure Search Index Status
# 238
# 🔹 Debug: Checking Azure Search Index Status
# 239
# 🔹 Debug: Checking Azure Search Index Status
# 241
# 🔹 Debug: Checking Azure Search Index Status
# 242
# 🔹 Debug: Checking Azure Search Index Status
# 242
# Processed 6 - Masonry.pdf: ✅ Document '6 - Masonry.pdf' processed and stored successfully!
# ✅ File '7 - Wood.pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-07-09 12:18:24.623272
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/cce-4360/7 - Wood.pdf?se=2026-07-09T12%3A18%3A24Z&sp=r&sv=2025-05-05&sr=b&sig=%2B1d30/ERzUqx%2BqW52rjmZ76yMvQINc6npTSn5di6qlo%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/cce-4360/7 - Wood.pdf?se=2026-07-09T12%3A18%3A24Z&sp=r&sv=2025-05-05&sr=b&sig=%2B1d30/ERzUqx%2BqW52rjmZ76yMvQINc6npTSn5di6qlo%3D
# 🔹 Debug: Checking Azure Search Index Status
# 243
# 🔹 Debug: Checking Azure Search Index Status
# 244
# 🔹 Debug: Checking Azure Search Index Status
# 246
# 🔹 Debug: Checking Azure Search Index Status
# 247
# 🔹 Debug: Checking Azure Search Index Status
# 248
# 🔹 Debug: Checking Azure Search Index Status
# 248
# 🔹 Debug: Checking Azure Search Index Status
# 249
# 🔹 Debug: Checking Azure Search Index Status
# 250
# 🔹 Debug: Checking Azure Search Index Status
# 251
# 🔹 Debug: Checking Azure Search Index Status
# 253
# 🔹 Debug: Checking Azure Search Index Status
# 253
# 🔹 Debug: Checking Azure Search Index Status
# 254
# 🔹 Debug: Checking Azure Search Index Status
# 255
# 🔹 Debug: Checking Azure Search Index Status
# 256
# 🔹 Debug: Checking Azure Search Index Status
# 257
# 🔹 Debug: Checking Azure Search Index Status
# 259
# 🔹 Debug: Checking Azure Search Index Status
# 259
# 🔹 Debug: Checking Azure Search Index Status
# 260
# 🔹 Debug: Checking Azure Search Index Status
# 261
# 🔹 Debug: Checking Azure Search Index Status
# 262
# 🔹 Debug: Checking Azure Search Index Status
# 264
# 🔹 Debug: Checking Azure Search Index Status
# 264
# 🔹 Debug: Checking Azure Search Index Status
# 265
# 🔹 Debug: Checking Azure Search Index Status
# 266
# 🔹 Debug: Checking Azure Search Index Status
# 267
# 🔹 Debug: Checking Azure Search Index Status
# 269
# 🔹 Debug: Checking Azure Search Index Status
# 270
# 🔹 Debug: Checking Azure Search Index Status
# 270
# 🔹 Debug: Checking Azure Search Index Status
# 271
# 🔹 Debug: Checking Azure Search Index Status
# 272
# 🔹 Debug: Checking Azure Search Index Status
# 273
# 🔹 Debug: Checking Azure Search Index Status
# 275
# 🔹 Debug: Checking Azure Search Index Status
# 275
# 🔹 Debug: Checking Azure Search Index Status
# 276
# 🔹 Debug: Checking Azure Search Index Status
# 277
# 🔹 Debug: Checking Azure Search Index Status
# 278
# 🔹 Debug: Checking Azure Search Index Status
# 280
# 🔹 Debug: Checking Azure Search Index Status
# 281
# 🔹 Debug: Checking Azure Search Index Status
# 281
# 🔹 Debug: Checking Azure Search Index Status
# 282
# 🔹 Debug: Checking Azure Search Index Status
# 283
# 🔹 Debug: Checking Azure Search Index Status
# 284
# 🔹 Debug: Checking Azure Search Index Status
# 285
# 🔹 Debug: Checking Azure Search Index Status
# 287
# 🔹 Debug: Checking Azure Search Index Status
# 288
# 🔹 Debug: Checking Azure Search Index Status
# 288
# 🔹 Debug: Checking Azure Search Index Status
# 289
# 🔹 Debug: Checking Azure Search Index Status
# 290
# 🔹 Debug: Checking Azure Search Index Status
# 291
# 🔹 Debug: Checking Azure Search Index Status
# 293
# 🔹 Debug: Checking Azure Search Index Status
# 294
# 🔹 Debug: Checking Azure Search Index Status
# 294
# 🔹 Debug: Checking Azure Search Index Status
# 295
# 🔹 Debug: Checking Azure Search Index Status
# 296
# 🔹 Debug: Checking Azure Search Index Status
# 297
# 🔹 Debug: Checking Azure Search Index Status
# 299
# 🔹 Debug: Checking Azure Search Index Status
# 300
# 🔹 Debug: Checking Azure Search Index Status
# 300
# 🔹 Debug: Checking Azure Search Index Status
# 301
# 🔹 Debug: Checking Azure Search Index Status
# 302
# 🔹 Debug: Checking Azure Search Index Status
# 303
# Processed 7 - Wood.pdf: ✅ Document '7 - Wood.pdf' processed and stored successfully!
# ✅ File '4 - Excavation.pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-07-09 12:19:33.934548
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/cce-4360/4 - Excavation.pdf?se=2026-07-09T12%3A19%3A33Z&sp=r&sv=2025-05-05&sr=b&sig=W4AyCI9cDPP/nC00ZqJeocf17c1HNtqxg6gtdiilySM%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/cce-4360/4 - Excavation.pdf?se=2026-07-09T12%3A19%3A33Z&sp=r&sv=2025-05-05&sr=b&sig=W4AyCI9cDPP/nC00ZqJeocf17c1HNtqxg6gtdiilySM%3D
# 🔹 Debug: Checking Azure Search Index Status
# 305
# 🔹 Debug: Checking Azure Search Index Status
# 306
# 🔹 Debug: Checking Azure Search Index Status
# 307
# 🔹 Debug: Checking Azure Search Index Status
# 307
# 🔹 Debug: Checking Azure Search Index Status
# 308
# 🔹 Debug: Checking Azure Search Index Status
# 309
# 🔹 Debug: Checking Azure Search Index Status
# 310
# 🔹 Debug: Checking Azure Search Index Status
# 311
# 🔹 Debug: Checking Azure Search Index Status
# 312
# 🔹 Debug: Checking Azure Search Index Status
# 314
# 🔹 Debug: Checking Azure Search Index Status
# 315
# 🔹 Debug: Checking Azure Search Index Status
# 315
# 🔹 Debug: Checking Azure Search Index Status
# 316
# 🔹 Debug: Checking Azure Search Index Status
# 317
# 🔹 Debug: Checking Azure Search Index Status
# 318
# 🔹 Debug: Checking Azure Search Index Status
# 319
# 🔹 Debug: Checking Azure Search Index Status
# 320
# 🔹 Debug: Checking Azure Search Index Status
# 321
# 🔹 Debug: Checking Azure Search Index Status
# 323
# 🔹 Debug: Checking Azure Search Index Status
# 323
# 🔹 Debug: Checking Azure Search Index Status
# 324
# 🔹 Debug: Checking Azure Search Index Status
# 325
# 🔹 Debug: Checking Azure Search Index Status
# 326
# 🔹 Debug: Checking Azure Search Index Status
# 327
# 🔹 Debug: Checking Azure Search Index Status
# 328
# 🔹 Debug: Checking Azure Search Index Status
# 329
# 🔹 Debug: Checking Azure Search Index Status
# 330
# 🔹 Debug: Checking Azure Search Index Status
# 331
# 🔹 Debug: Checking Azure Search Index Status
# 332
# 🔹 Debug: Checking Azure Search Index Status
# 333
# 🔹 Debug: Checking Azure Search Index Status
# 334
# 🔹 Debug: Checking Azure Search Index Status
# 336
# 🔹 Debug: Checking Azure Search Index Status
# 337
# 🔹 Debug: Checking Azure Search Index Status
# 337
# 🔹 Debug: Checking Azure Search Index Status
# 338
# 🔹 Debug: Checking Azure Search Index Status
# 339
# 🔹 Debug: Checking Azure Search Index Status
# 340
# 🔹 Debug: Checking Azure Search Index Status
# 342
# 🔹 Debug: Checking Azure Search Index Status
# 343
# 🔹 Debug: Checking Azure Search Index Status
# 344
# Processed 4 - Excavation.pdf: ✅ Document '4 - Excavation.pdf' processed and stored successfully!
# ✅ File '1 - Estimating Basics.pdf' uploaded successfully.
# ✅ SAS URL generated successfully! Expires on: 2026-07-09 12:20:23.619934
# ✅ SAS URL: https://mtugenai.blob.core.windows.net/cce-4360/1 - Estimating Basics.pdf?se=2026-07-09T12%3A20%3A23Z&sp=r&sv=2025-05-05&sr=b&sig=p4lnVp/9ATDSX6SpApKqwnk2hIu03ehVDhq9qt3CqhM%3D
# 🔹 Debug: Trying to analyze document from URL: https://mtugenai.blob.core.windows.net/cce-4360/1 - Estimating Basics.pdf?se=2026-07-09T12%3A20%3A23Z&sp=r&sv=2025-05-05&sr=b&sig=p4lnVp/9ATDSX6SpApKqwnk2hIu03ehVDhq9qt3CqhM%3D
# 🔹 Debug: Checking Azure Search Index Status
# 344
# 🔹 Debug: Checking Azure Search Index Status
# 345
# 🔹 Debug: Checking Azure Search Index Status
# 346
# 🔹 Debug: Checking Azure Search Index Status
# 347
# 🔹 Debug: Checking Azure Search Index Status
# 348
# 🔹 Debug: Checking Azure Search Index Status
# 349
# 🔹 Debug: Checking Azure Search Index Status
# 350
# 🔹 Debug: Checking Azure Search Index Status
# 351
# 🔹 Debug: Checking Azure Search Index Status
# 352
# 🔹 Debug: Checking Azure Search Index Status
# 354
# 🔹 Debug: Checking Azure Search Index Status
# 355
# 🔹 Debug: Checking Azure Search Index Status
# 355
# 🔹 Debug: Checking Azure Search Index Status
# 356
# 🔹 Debug: Checking Azure Search Index Status
# 357
# 🔹 Debug: Checking Azure Search Index Status
# 358
# 🔹 Debug: Checking Azure Search Index Status
# 359
# 🔹 Debug: Checking Azure Search Index Status
# 361
# 🔹 Debug: Checking Azure Search Index Status
# 362
# 🔹 Debug: Checking Azure Search Index Status
# 362
# 🔹 Debug: Checking Azure Search Index Status
# 363
# 🔹 Debug: Checking Azure Search Index Status
# 364
# Processed 1 - Estimating Basics.pdf: ✅ Document '1 - Estimating Basics.pdf' processed and stored successfully!
